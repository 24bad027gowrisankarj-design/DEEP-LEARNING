# %%
# ======================================================
# Part A
# Roll No: 24BAD027n
# Name: Gowri Sankar J
# ======================================================

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Input values
x = np.linspace(-10, 10, 200)

# Activation Functions
sigmoid = tf.keras.activations.sigmoid(x)
tanh = tf.keras.activations.tanh(x)
relu = tf.keras.activations.relu(x)

# Plot
plt.figure(figsize=(10,6))
plt.plot(x, sigmoid, label='Sigmoid')
plt.plot(x, tanh, label='Tanh')
plt.plot(x, relu, label='ReLU')

plt.title("Activation Functions")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.legend()
plt.show()

# %%
# ======================================================
# Part B
# Roll No: 24BAD027n
# Name: Gowri Sankar J
# ======================================================

import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Load Dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0


# Function to create ANN
def create_model(activation):

    model = Sequential([
        Flatten(input_shape=(28,28)),
        Dense(128, activation=activation),
        Dense(64, activation=activation),
        Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model


activations = ['sigmoid', 'tanh', 'relu']

histories = {}

for act in activations:

    print(f"\nTraining using {act}")

    model = create_model(act)

    history = model.fit(
        x_train,
        y_train,
        epochs=10,
        validation_split=0.2,
        verbose=1
    )

    histories[act] = history

    loss, acc = model.evaluate(x_test, y_test, verbose=0)

    print(f"Test Accuracy ({act}) = {acc:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
#
# Training using sigmoid
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\nisha\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.8704 - loss: 0.5239 - val_accuracy: 0.9352 - val_loss: 0.2312
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9412 - loss: 0.1976 - val_accuracy: 0.9532 - val_loss: 0.1634
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9583 - loss: 0.1402 - val_accuracy: 0.9613 - val_loss: 0.1328
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9686 - loss: 0.1051 - val_accuracy: 0.9657 - val_loss: 0.1162
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9757 - loss: 0.0813 - val_accuracy: 0.9699 - val_loss: 0.1051
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9812 - loss: 0.0647 - val_accuracy: 0.9695 - val_loss: 0.1004
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9848 - loss: 0.0516 - val_accuracy: 0.9732 - val_loss: 0.0921
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9883 - loss: 0.0419 - val_accuracy: 0.9709 - val_loss: 0.0925
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9910 - loss: 0.0326 - val_accuracy: 0.9733 - val_loss: 0.0933
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9929 - loss: 0.0268 - val_accuracy: 0.9752 - val_loss: 0.0885
# Test Accuracy (sigmoid) = 0.9743
#
# Training using tanh
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9154 - loss: 0.2923 - val_accuracy: 0.9499 - val_loss: 0.1705
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9606 - loss: 0.1329 - val_accuracy: 0.9649 - val_loss: 0.1228
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9731 - loss: 0.0899 - val_accuracy: 0.9701 - val_loss: 0.0973
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9805 - loss: 0.0651 - val_accuracy: 0.9679 - val_loss: 0.1011
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9836 - loss: 0.0510 - val_accuracy: 0.9720 - val_loss: 0.0916
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9880 - loss: 0.0379 - val_accuracy: 0.9729 - val_loss: 0.0926
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9914 - loss: 0.0295 - val_accuracy: 0.9744 - val_loss: 0.0875
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9922 - loss: 0.0238 - val_accuracy: 0.9741 - val_loss: 0.0952
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9944 - loss: 0.0185 - val_accuracy: 0.9703 - val_loss: 0.1095
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9956 - loss: 0.0163 - val_accuracy: 0.9732 - val_loss: 0.0999
# Test Accuracy (tanh) = 0.9738
#
# Training using relu
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9217 - loss: 0.2705 - val_accuracy: 0.9535 - val_loss: 0.1590
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9661 - loss: 0.1116 - val_accuracy: 0.9637 - val_loss: 0.1175
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9760 - loss: 0.0774 - val_accuracy: 0.9722 - val_loss: 0.0947
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9814 - loss: 0.0590 - val_accuracy: 0.9737 - val_loss: 0.0897
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9860 - loss: 0.0442 - val_accuracy: 0.9726 - val_loss: 0.0959
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9889 - loss: 0.0358 - val_accuracy: 0.9686 - val_loss: 0.1072
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9901 - loss: 0.0299 - val_accuracy: 0.9754 - val_loss: 0.0967
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9919 - loss: 0.0245 - val_accuracy: 0.9728 - val_loss: 0.1075
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9936 - loss: 0.0198 - val_accuracy: 0.9762 - val_loss: 0.0935
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9927 - loss: 0.0221 - val_accuracy: 0.9758 - val_loss: 0.0996
# Test Accuracy (relu) = 0.9788

# %%
plt.figure(figsize=(10,5))

for act in activations:
    plt.plot(histories[act].history['val_accuracy'], label=act)

plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))

for act in activations:
    plt.plot(histories[act].history['val_loss'], label=act)

plt.title("Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ======================================================
# Part C
# Roll No: 24BAD027n
# Name: Gowri Sankar J
# ======================================================

from tensorflow.keras.optimizers import SGD, RMSprop, Adam

optimizers = {
    "SGD": SGD(),
    "Momentum": SGD(momentum=0.9),
    "RMSProp": RMSprop(),
    "Adam": Adam()
}

optimizer_history = {}

for name, opt in optimizers.items():

    print(f"\nTraining using {name}")

    model = Sequential([
        Flatten(input_shape=(28,28)),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=opt,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    history = model.fit(
        x_train,
        y_train,
        epochs=10,
        validation_split=0.2,
        verbose=1
    )

    optimizer_history[name] = history

    loss, acc = model.evaluate(x_test, y_test, verbose=0)

    print(f"{name} Accuracy = {acc:.4f}")
# Out:
# Training using SGD
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8236 - loss: 0.6664 - val_accuracy: 0.9074 - val_loss: 0.3284
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9092 - loss: 0.3177 - val_accuracy: 0.9240 - val_loss: 0.2667
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9248 - loss: 0.2639 - val_accuracy: 0.9320 - val_loss: 0.2356
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9349 - loss: 0.2297 - val_accuracy: 0.9423 - val_loss: 0.2077
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9421 - loss: 0.2035 - val_accuracy: 0.9480 - val_loss: 0.1922
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9474 - loss: 0.1830 - val_accuracy: 0.9521 - val_loss: 0.1740
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9525 - loss: 0.1656 - val_accuracy: 0.9551 - val_loss: 0.1610
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9563 - loss: 0.1511 - val_accuracy: 0.9566 - val_loss: 0.1518
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9606 - loss: 0.1385 - val_accuracy: 0.9586 - val_loss: 0.1451
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9632 - loss: 0.1278 - val_accuracy: 0.9616 - val_loss: 0.1362
# SGD Accuracy = 0.9616
#
# Training using Momentum
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9029 - loss: 0.3283 - val_accuracy: 0.9532 - val_loss: 0.1607
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9568 - loss: 0.1406 - val_accuracy: 0.9665 - val_loss: 0.1153
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9706 - loss: 0.0944 - val_accuracy: 0.9632 - val_loss: 0.1192
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9780 - loss: 0.0723 - val_accuracy: 0.9743 - val_loss: 0.0867
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9825 - loss: 0.0560 - val_accuracy: 0.9749 - val_loss: 0.0869
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9862 - loss: 0.0438 - val_accuracy: 0.9747 - val_loss: 0.0905
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9895 - loss: 0.0343 - val_accuracy: 0.9766 - val_loss: 0.0876
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9914 - loss: 0.0283 - val_accuracy: 0.9762 - val_loss: 0.0855
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9939 - loss: 0.0211 - val_accuracy: 0.9776 - val_loss: 0.0859
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9944 - loss: 0.0186 - val_accuracy: 0.9750 - val_loss: 0.0939
# Momentum Accuracy = 0.9774
#
# Training using RMSProp
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9216 - loss: 0.2657 - val_accuracy: 0.9509 - val_loss: 0.1603
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9636 - loss: 0.1183 - val_accuracy: 0.9663 - val_loss: 0.1134
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9749 - loss: 0.0844 - val_accuracy: 0.9708 - val_loss: 0.0973
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9804 - loss: 0.0658 - val_accuracy: 0.9732 - val_loss: 0.1031
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9839 - loss: 0.0545 - val_accuracy: 0.9741 - val_loss: 0.1106
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9864 - loss: 0.0451 - val_accuracy: 0.9758 - val_loss: 0.1109
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9881 - loss: 0.0386 - val_accuracy: 0.9726 - val_loss: 0.1108
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9905 - loss: 0.0326 - val_accuracy: 0.9762 - val_loss: 0.1193
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9920 - loss: 0.0288 - val_accuracy: 0.9772 - val_loss: 0.1176
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9931 - loss: 0.0242 - val_accuracy: 0.9743 - val_loss: 0.1299
# RMSProp Accuracy = 0.9763
#
# Training using Adam
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9228 - loss: 0.2650 - val_accuracy: 0.9625 - val_loss: 0.1327
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9660 - loss: 0.1094 - val_accuracy: 0.9617 - val_loss: 0.1277
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9770 - loss: 0.0759 - val_accuracy: 0.9697 - val_loss: 0.1033
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9810 - loss: 0.0577 - val_accuracy: 0.9744 - val_loss: 0.0910
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9860 - loss: 0.0448 - val_accuracy: 0.9699 - val_loss: 0.1044
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9886 - loss: 0.0355 - val_accuracy: 0.9754 - val_loss: 0.0959
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9897 - loss: 0.0308 - val_accuracy: 0.9743 - val_loss: 0.0991
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9917 - loss: 0.0248 - val_accuracy: 0.9747 - val_loss: 0.0991
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9930 - loss: 0.0216 - val_accuracy: 0.9759 - val_loss: 0.1009
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9939 - loss: 0.0180 - val_accuracy: 0.9754 - val_loss: 0.1093
# Adam Accuracy = 0.9768

# %%
plt.figure(figsize=(10,5))

for name in optimizer_history:
    plt.plot(
        optimizer_history[name].history['val_loss'],
        label=name
    )

plt.title("Optimizer Comparison (Loss)")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# ======================================================
# Part D
# Roll No: 24BAD027n
# Name: Gowri Sankar J
# ======================================================

import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Create the model
model = Sequential([
    tf.keras.layers.Input(shape=(4,)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(3, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Display model summary
model.summary()

# Directory where the model will be saved
save_dir = "/content/drive/MyDrive/24BAD027/24ADI006L-24BAD027/EX02"

# Create the directory if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Save the model
model_path = os.path.join(save_dir, "EX02.keras")
model.save(model_path)

print(f"Model Saved Successfully at:\n{model_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 243 (972.00 B)
#  Trainable params: 243 (972.00 B)
#  Non-trainable params: 0 (0.00 B)
# Model Saved Successfully at:
# /content/drive/MyDrive/24BAD027/24ADI006L-24BAD027/EX02/EX02.keras
